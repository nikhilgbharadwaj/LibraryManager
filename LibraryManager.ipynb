# %%
t=['abc','csaxd','asd','aasdx']
a=['a','b','c','d']
g=['u','v','w','x']
s={'abc':'To Read','csaxd':'Reading','asd':'Reading','aasdx':'Read'}
r={'abc':4,'csaxd':2,'asd':1,'aasdx':3}
s=['To Read','Reading','Read']



ipfromuser=input('Let the library bot know what you want \n by entering the number!!! \n 1 - Add book to our library \n 2 - See all the books in the library \n 3- Edit the book \n 4 - See all books by genere \n 5 - See all books by status \n ')
match ipfromuser:

  case 1:
    bName=input('Enter Bok name')
    bAuthor=input('Enter author')
    bGenre=input('Enter Genre')
    bStatus=input('Enter status: To Read, Reading, Read ')
    brating = input('Enter Book Rating')
    addBook(bName,bAuthor,bGenre,bStatus,brating)


  case 2:
    listallbooks()

  case 3:
    editBook()



  case 4:
    listByGenre()


  case 5:
    listByStatus()



def addBook(book, author, genre, status, rating):
  t.append(book)
  a.append(author)
  g.append(genre)
  s.append(status)
  r.append(rating)


def listallbooks():
  for i in range(len(t)):
    print('Book: ', end='')
    print(t[i], end=' ')

    print('Author: ', end='')
    print(a[i], end=' ')

    print('Genre: ', end='')
    print(g[i], end=' ')

    print('Rating: ')
    print(r[i])



def editBook():
  pass


def listByGenre():
  pass

def listByStatus():
  pass
